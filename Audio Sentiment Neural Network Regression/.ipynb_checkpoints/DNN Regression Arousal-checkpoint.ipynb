# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import csv
import pandas as pd
print(tf.__version__)
# Out:
# 1.10.0

# %%
# LOAD DATA
x_train = np.load("train_x.npy")
valence_y_train = np.load("valence_train_y.npy")
arousal_y_train = np.load("arousal_train_y.npy")
x_test = np.load("test_x.npy")
valence_y_test = np.load("valence_test_y.npy")
arousal_y_test = np.load("arousal_test_y.npy")

valence_y_train = valence_y_train.flatten()
arousal_y_train = arousal_y_train.flatten()
valence_y_test = valence_y_test.flatten()
arousal_y_test = arousal_y_test.flatten()

# Shuffle the training set
order = np.argsort(np.random.random(valence_y_train.shape))
x_train = x_train[order]
valence_y_train = valence_y_train[order]
arousal_y_train = arousal_y_train[order]

print("training set: {}".format(x_train.shape))
print("valence_y_train: {}".format(valence_y_train.shape))
print("arousal_y_train: {}".format(arousal_y_train.shape))
print("testing set: {}".format(x_test.shape))
print("valence_y_test: {}".format(valence_y_test.shape))
print("arousal_y_test: {}".format(arousal_y_test.shape))
# Out:
# training set: (1351, 193)
# valence_y_train: (1351,)
# arousal_y_train: (1351,)
# testing set: (451, 193)
# valence_y_test: (451,)
# arousal_y_test: (451,)

# %%
# Normalize the data

print(x_train[0][1], type(x_train[0][1]))  # Display sample features, notice the different scales

# Using mean and standard deviation
# mean = x_train.mean(axis=0)
# std = x_train.std(axis=0)
# x_train = (x_train - mean) / std
# x_test = (x_test - mean) / std

# Using keras utilities normalize
x_train = tf.keras.utils.normalize(x_train, axis=1)  # scales data between 0 and 1
x_test = tf.keras.utils.normalize(x_test, axis=1)  # scales data between 0 and 1

print(x_train[0][1], type(x_train[0][1]))
# Out:
# 195.7454161373171 <class 'numpy.float64'>
# 0.5193472608572921 <class 'numpy.float64'>

# %%
def build_model():
  model = keras.Sequential([
    keras.layers.Dense(64, activation=tf.nn.relu, 
                       input_shape=(x_train.shape[1],)),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(1)
  ])

  optimizer = tf.train.RMSPropOptimizer(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae'])
  return model

model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 16,641
# Trainable params: 16,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Display training progress by printing a single dot for each completed epoch.
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

# Store training stats
history = model.fit(x_train, valence_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
import matplotlib.pyplot as plt


def plot_history(history):
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Valence]')
  plt.plot(history.epoch, np.array(history.history['mean_absolute_error']), 
           label='Train Loss')
  plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
           label = 'Val loss')
  plt.legend()
  plt.ylim([0,5])

# %%
plot_history(history)

# %%
model = build_model()

# The patience parameter is the amount of epochs to check for improvement.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(x_train, valence_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# .........................................

# %%
[loss, mae] = model.evaluate(x_test, valence_y_test, verbose=0)

print("Testing set Mean Abs Error:{:7.2f}".format(mae))
# Out:
# Testing set Mean Abs Error:   0.80

# %%
test_predictions = model.predict(x_test).flatten()

print(len(test_predictions))
print(len(valence_y_test))
# Out:
# 451
# 451

# %%
ctr=0
nctr=0
for i in range(len(valence_y_test)):
    diff = abs(test_predictions[i] - valence_y_test[i])
    if(diff < 3):
        ctr = ctr + 1
        print("ctr[{0:}] - expected: {1:.1f}, prediction: {2:.1f}".format(ctr,test_predictions[i],valence_y_test[i]))
    else:
        nctr = nctr + 1
        diff = abs(test_predictions[i] - valence_y_test[i])
        print("test[{}] - values different by {:.1f}".format(i,diff))
    
print("ctr: {}\nnctr: {}".format(ctr,nctr))

print("test[436] - expected: {0:.1f}, prediction: {1:.1f}".format(test_predictions[436],valence_y_test[436]))
# Out:
# ctr[1] - expected: 6.0, prediction: 4.5
# ctr[2] - expected: 5.7, prediction: 6.4
# ctr[3] - expected: 4.5, prediction: 6.4
# ctr[4] - expected: 5.5, prediction: 5.7
# ctr[5] - expected: 4.4, prediction: 3.8
# ctr[6] - expected: 6.0, prediction: 6.2
# ctr[7] - expected: 5.1, prediction: 6.6
# ctr[8] - expected: 5.1, prediction: 5.7
# ctr[9] - expected: 5.9, prediction: 4.8
# ctr[10] - expected: 4.7, prediction: 6.1
# ctr[11] - expected: 5.5, prediction: 6.1
# ctr[12] - expected: 5.9, prediction: 5.2
# ctr[13] - expected: 5.8, prediction: 6.3
# ctr[14] - expected: 5.1, prediction: 6.1
# ctr[15] - expected: 5.2, prediction: 6.0
# ctr[16] - expected: 4.8, prediction: 5.6
# ctr[17] - expected: 5.2, prediction: 5.7
# ctr[18] - expected: 5.4, prediction: 4.9
# ctr[19] - expected: 6.0, prediction: 6.1
# ctr[20] - expected: 4.5, prediction: 4.4
# ctr[21] - expected: 4.5, prediction: 4.7
# ctr[22] - expected: 5.1, prediction: 6.4
# ctr[23] - expected: 5.1, prediction: 6.0
# ctr[24] - expected: 5.4, prediction: 5.7
# ctr[25] - expected: 4.1, prediction: 5.2
# ctr[26] - expected: 5.8, prediction: 6.5
# ctr[27] - expected: 5.2, prediction: 5.5
# ctr[28] - expected: 5.8, prediction: 6.8
# ctr[29] - expected: 5.8, prediction: 4.6
# ctr[30] - expected: 5.2, prediction: 5.5
# ctr[31] - expected: 4.3, prediction: 5.9
# ctr[32] - expected: 5.1, prediction: 5.3
# ctr[33] - expected: 5.4, prediction: 6.6
# ctr[34] - expected: 5.5, prediction: 4.6
# ctr[35] - expected: 4.6, prediction: 5.1
# ctr[36] - expected: 5.5, prediction: 4.4
# ctr[37] - expected: 5.1, prediction: 5.0
# ctr[38] - expected: 5.3, prediction: 5.8
# ctr[39] - expected: 4.3, prediction: 4.5
# ctr[40] - expected: 5.3, prediction: 7.1
# ctr[41] - expected: 3.4, prediction: 3.9
# ctr[42] - expected: 4.9, prediction: 6.1
# ctr[43] - expected: 5.3, prediction: 5.9
# ctr[44] - expected: 5.5, prediction: 4.8
# ctr[45] - expected: 5.8, prediction: 7.2
# ctr[46] - expected: 4.2, prediction: 4.3
# ctr[47] - expected: 4.6, prediction: 4.8
# ctr[48] - expected: 5.2, prediction: 6.1
# ctr[49] - expected: 4.5, prediction: 4.7
# ctr[50] - expected: 5.0, prediction: 5.6
# ctr[51] - expected: 4.9, prediction: 6.2
# ctr[52] - expected: 4.9, prediction: 4.6
# ctr[53] - expected: 4.8, prediction: 5.2
# ctr[54] - expected: 6.1, prediction: 5.7
# ctr[55] - expected: 5.2, prediction: 6.1
# ctr[56] - expected: 4.9, prediction: 4.6
# ctr[57] - expected: 4.4, prediction: 4.2
# ctr[58] - expected: 5.3, prediction: 5.6
# ctr[59] - expected: 4.1, prediction: 3.8
# ctr[60] - expected: 5.7, prediction: 6.0
# ctr[61] - expected: 5.2, prediction: 5.5
# ctr[62] - expected: 4.5, prediction: 5.5
# ctr[63] - expected: 5.2, prediction: 5.9
# ctr[64] - expected: 4.6, prediction: 4.2
# ctr[65] - expected: 4.0, prediction: 4.4
# ctr[66] - expected: 4.9, prediction: 6.1
# ctr[67] - expected: 5.7, prediction: 5.0
# ctr[68] - expected: 6.0, prediction: 5.5
# ctr[69] - expected: 4.6, prediction: 5.6
# ctr[70] - expected: 5.0, prediction: 6.8
# ctr[71] - expected: 5.1, prediction: 5.1
# ctr[72] - expected: 5.1, prediction: 5.4
# ctr[73] - expected: 6.1, prediction: 6.8
# ctr[74] - expected: 5.0, prediction: 5.0
# ctr[75] - expected: 5.3, prediction: 6.1
# ctr[76] - expected: 4.4, prediction: 6.0
# ctr[77] - expected: 4.9, prediction: 5.1
# ctr[78] - expected: 4.6, prediction: 5.4
# ctr[79] - expected: 4.3, prediction: 3.7
# ctr[80] - expected: 5.2, prediction: 5.1
# ctr[81] - expected: 5.5, prediction: 5.2
# ctr[82] - expected: 5.4, prediction: 7.1
# ctr[83] - expected: 4.7, prediction: 5.4
# ctr[84] - expected: 4.4, prediction: 3.7
# ctr[85] - expected: 4.1, prediction: 3.8
# ctr[86] - expected: 4.4, prediction: 4.4
# ctr[87] - expected: 5.8, prediction: 4.5
# ctr[88] - expected: 4.9, prediction: 5.7
# ctr[89] - expected: 4.2, prediction: 3.8
# ctr[90] - expected: 4.0, prediction: 3.3
# ctr[91] - expected: 4.6, prediction: 4.5
# ctr[92] - expected: 4.9, prediction: 5.1
# ctr[93] - expected: 5.0, prediction: 5.6
# ctr[94] - expected: 3.6, prediction: 4.0
# ctr[95] - expected: 3.5, prediction: 4.1
# ctr[96] - expected: 5.4, prediction: 5.3
# ctr[97] - expected: 5.7, prediction: 5.3
# ctr[98] - expected: 5.8, prediction: 4.0
# ctr[99] - expected: 4.9, prediction: 4.9
# ctr[100] - expected: 3.8, prediction: 3.5
# ctr[101] - expected: 3.7, prediction: 4.2
# ctr[102] - expected: 4.6, prediction: 4.0
# ctr[103] - expected: 4.7, prediction: 3.6
# ctr[104] - expected: 4.7, prediction: 5.0
# ctr[105] - expected: 4.3, prediction: 4.4
# ctr[106] - expected: 5.4, prediction: 6.2
# ctr[107] - expected: 4.4, prediction: 6.1
# ctr[108] - expected: 5.1, prediction: 5.9
# ctr[109] - expected: 5.0, prediction: 5.8
# ctr[110] - expected: 4.8, prediction: 6.0
# ctr[111] - expected: 4.8, prediction: 4.7
# ctr[112] - expected: 3.6, prediction: 5.0
# ctr[113] - expected: 4.8, prediction: 7.5
# ctr[114] - expected: 3.7, prediction: 4.2
# ctr[115] - expected: 3.9, prediction: 5.0
# ctr[116] - expected: 4.3, prediction: 4.3
# ctr[117] - expected: 3.8, prediction: 3.7
# ctr[118] - expected: 4.9, prediction: 5.2
# ctr[119] - expected: 4.4, prediction: 4.6
# ctr[120] - expected: 5.1, prediction: 4.9
# ctr[121] - expected: 4.7, prediction: 3.1
# ctr[122] - expected: 5.3, prediction: 5.1
# ctr[123] - expected: 5.0, prediction: 5.3
# ctr[124] - expected: 4.5, prediction: 4.2
# ctr[125] - expected: 4.3, prediction: 4.2
# ctr[126] - expected: 3.6, prediction: 3.8
# ctr[127] - expected: 5.1, prediction: 5.1
# ctr[128] - expected: 4.9, prediction: 4.7
# ctr[129] - expected: 4.9, prediction: 4.7
# ctr[130] - expected: 4.2, prediction: 3.6
# ctr[131] - expected: 4.6, prediction: 2.8
# ctr[132] - expected: 3.8, prediction: 3.7
# ctr[133] - expected: 5.3, prediction: 5.3
# ctr[134] - expected: 4.6, prediction: 3.3
# ctr[135] - expected: 5.4, prediction: 6.8
# ctr[136] - expected: 4.7, prediction: 6.8
# ctr[137] - expected: 4.8, prediction: 4.9
# ctr[138] - expected: 5.3, prediction: 7.1
# ctr[139] - expected: 5.5, prediction: 5.7
# ctr[140] - expected: 4.2, prediction: 4.3
# ctr[141] - expected: 4.8, prediction: 5.4
# ctr[142] - expected: 5.2, prediction: 6.7
# ctr[143] - expected: 5.1, prediction: 4.7
# ctr[144] - expected: 4.6, prediction: 4.1
# ctr[145] - expected: 5.6, prediction: 5.5
# ctr[146] - expected: 4.4, prediction: 3.2
# ctr[147] - expected: 4.2, prediction: 4.2
# ctr[148] - expected: 5.2, prediction: 6.4
# ctr[149] - expected: 3.7, prediction: 4.4
# ctr[150] - expected: 3.5, prediction: 5.0
# ctr[151] - expected: 4.9, prediction: 5.4
# ctr[152] - expected: 4.8, prediction: 5.4
# ctr[153] - expected: 5.7, prediction: 4.3
# ctr[154] - expected: 5.9, prediction: 7.9
# ctr[155] - expected: 5.1, prediction: 6.1
# ctr[156] - expected: 3.9, prediction: 4.4
# ctr[157] - expected: 4.1, prediction: 4.9
# ctr[158] - expected: 5.1, prediction: 5.8
# ctr[159] - expected: 4.0, prediction: 3.7
# ctr[160] - expected: 3.1, prediction: 3.8
# ctr[161] - expected: 4.1, prediction: 4.1
# ctr[162] - expected: 4.6, prediction: 5.9
# ctr[163] - expected: 3.9, prediction: 4.5
# ctr[164] - expected: 5.2, prediction: 4.9
# ctr[165] - expected: 3.8, prediction: 5.6
# ctr[166] - expected: 4.0, prediction: 5.4
# ctr[167] - expected: 4.9, prediction: 4.9
# ctr[168] - expected: 3.6, prediction: 4.6
# ctr[169] - expected: 3.7, prediction: 4.8
# ctr[170] - expected: 4.0, prediction: 5.3
# ctr[171] - expected: 3.2, prediction: 4.4
# ctr[172] - expected: 3.5, prediction: 5.7
# ctr[173] - expected: 3.8, prediction: 4.8
# ctr[174] - expected: 3.4, prediction: 4.2
# ctr[175] - expected: 4.7, prediction: 4.7
# ctr[176] - expected: 5.0, prediction: 4.2
# ctr[177] - expected: 4.6, prediction: 5.5
# ctr[178] - expected: 4.8, prediction: 5.6
# ctr[179] - expected: 3.5, prediction: 4.2
# ctr[180] - expected: 5.3, prediction: 3.9
# ctr[181] - expected: 5.5, prediction: 3.6
# ctr[182] - expected: 4.7, prediction: 5.9
# ctr[183] - expected: 3.4, prediction: 3.8
# ctr[184] - expected: 4.4, prediction: 5.3
# ctr[185] - expected: 5.7, prediction: 6.1
# ctr[186] - expected: 4.7, prediction: 5.1
# ctr[187] - expected: 4.8, prediction: 4.2
# ctr[188] - expected: 4.5, prediction: 3.9
# ctr[189] - expected: 5.4, prediction: 5.8
# ctr[190] - expected: 4.2, prediction: 3.6
# ctr[191] - expected: 5.0, prediction: 5.7
# ctr[192] - expected: 4.6, prediction: 5.8
# ctr[193] - expected: 3.7, prediction: 3.4
# ctr[194] - expected: 3.9, prediction: 3.4
# ctr[195] - expected: 5.6, prediction: 5.7
# ctr[196] - expected: 4.7, prediction: 4.1
# ctr[197] - expected: 5.6, prediction: 5.7
# ctr[198] - expected: 5.7, prediction: 5.7
# ctr[199] - expected: 5.7, prediction: 6.5
# ctr[200] - expected: 5.5, prediction: 5.7
# ctr[201] - expected: 5.8, prediction: 5.4
# ctr[202] - expected: 5.5, prediction: 4.0
# ctr[203] - expected: 4.7, prediction: 4.1
# ctr[204] - expected: 5.8, prediction: 4.6
# ctr[205] - expected: 5.5, prediction: 5.0
# ctr[206] - expected: 5.5, prediction: 6.1
# ctr[207] - expected: 5.6, prediction: 6.0
# ctr[208] - expected: 5.2, prediction: 6.4
# ctr[209] - expected: 4.8, prediction: 5.0
# ctr[210] - expected: 5.6, prediction: 6.6
# ctr[211] - expected: 4.1, prediction: 4.3
# ctr[212] - expected: 5.0, prediction: 4.1
# ctr[213] - expected: 5.9, prediction: 4.5
# ctr[214] - expected: 5.3, prediction: 6.2
# ctr[215] - expected: 4.5, prediction: 4.7
# ctr[216] - expected: 4.5, prediction: 2.7
# ctr[217] - expected: 5.1, prediction: 6.2
# ctr[218] - expected: 5.3, prediction: 4.8
# ctr[219] - expected: 5.1, prediction: 5.1
# ctr[220] - expected: 6.1, prediction: 5.6
# ctr[221] - expected: 6.3, prediction: 5.8
# ctr[222] - expected: 4.5, prediction: 4.8
# ctr[223] - expected: 5.4, prediction: 5.7
# ctr[224] - expected: 6.0, prediction: 6.2
# ctr[225] - expected: 4.5, prediction: 5.7
# ctr[226] - expected: 4.7, prediction: 4.5
# ctr[227] - expected: 5.0, prediction: 6.3
# ctr[228] - expected: 4.8, prediction: 5.3
# ctr[229] - expected: 4.8, prediction: 5.6
# ctr[230] - expected: 4.2, prediction: 4.2
# ctr[231] - expected: 5.1, prediction: 4.6
# ctr[232] - expected: 5.5, prediction: 6.0
# ctr[233] - expected: 4.8, prediction: 4.8
# ctr[234] - expected: 5.5, prediction: 4.6
# ctr[235] - expected: 5.7, prediction: 5.8
# ctr[236] - expected: 4.5, prediction: 4.9
# ctr[237] - expected: 4.9, prediction: 6.1
# ctr[238] - expected: 5.5, prediction: 5.9
# ctr[239] - expected: 5.6, prediction: 5.8
# ctr[240] - expected: 4.1, prediction: 3.2
# ctr[241] - expected: 5.6, prediction: 5.5
# ctr[242] - expected: 4.8, prediction: 6.0
# ctr[243] - expected: 3.9, prediction: 3.7
# ctr[244] - expected: 4.0, prediction: 4.6
# ctr[245] - expected: 4.7, prediction: 4.1
# ctr[246] - expected: 5.3, prediction: 6.5
# ctr[247] - expected: 5.4, prediction: 5.2
# ctr[248] - expected: 4.9, prediction: 5.4
# ctr[249] - expected: 5.6, prediction: 6.1
# ctr[250] - expected: 5.3, prediction: 5.3
# ctr[251] - expected: 5.6, prediction: 5.2
# ctr[252] - expected: 4.7, prediction: 5.2
# ctr[253] - expected: 4.2, prediction: 3.7
# ctr[254] - expected: 4.8, prediction: 5.1
# ctr[255] - expected: 5.0, prediction: 5.1
# ctr[256] - expected: 5.3, prediction: 6.4
# ctr[257] - expected: 6.0, prediction: 6.1
# ctr[258] - expected: 5.3, prediction: 6.8
# ctr[259] - expected: 4.1, prediction: 4.8
# ctr[260] - expected: 4.1, prediction: 4.2
# ctr[261] - expected: 5.4, prediction: 5.8
# ctr[262] - expected: 3.6, prediction: 4.1
# ctr[263] - expected: 5.2, prediction: 5.4
# ctr[264] - expected: 5.7, prediction: 6.4
# ctr[265] - expected: 5.3, prediction: 4.5
# ctr[266] - expected: 4.6, prediction: 4.7
# ctr[267] - expected: 5.4, prediction: 5.0
# ctr[268] - expected: 4.4, prediction: 6.3
# ctr[269] - expected: 5.0, prediction: 6.3
# ctr[270] - expected: 5.7, prediction: 6.2
# ctr[271] - expected: 5.4, prediction: 6.7
# ctr[272] - expected: 5.3, prediction: 5.4
# ctr[273] - expected: 5.5, prediction: 5.4
# ctr[274] - expected: 4.7, prediction: 5.0
# ctr[275] - expected: 5.6, prediction: 5.5
# ctr[276] - expected: 5.1, prediction: 5.6
# ctr[277] - expected: 5.9, prediction: 6.5
# ctr[278] - expected: 5.0, prediction: 3.9
# ctr[279] - expected: 3.9, prediction: 4.1
# ctr[280] - expected: 5.4, prediction: 6.0
# ctr[281] - expected: 2.8, prediction: 3.4
# ctr[282] - expected: 5.6, prediction: 5.6
# ctr[283] - expected: 4.8, prediction: 6.0
# ctr[284] - expected: 4.2, prediction: 5.0
# ctr[285] - expected: 5.9, prediction: 5.1
# ctr[286] - expected: 4.9, prediction: 6.3
# ctr[287] - expected: 5.1, prediction: 4.8
# ctr[288] - expected: 4.6, prediction: 6.5
# ctr[289] - expected: 4.5, prediction: 4.9
# ctr[290] - expected: 4.4, prediction: 4.2
# ctr[291] - expected: 5.4, prediction: 5.1
# ctr[292] - expected: 3.7, prediction: 5.0
# ctr[293] - expected: 5.8, prediction: 6.5
# ctr[294] - expected: 5.0, prediction: 5.2
# ctr[295] - expected: 6.0, prediction: 4.4
# ctr[296] - expected: 6.1, prediction: 3.2
# ctr[297] - expected: 5.0, prediction: 4.1
# ctr[298] - expected: 5.9, prediction: 3.7
# ctr[299] - expected: 5.1, prediction: 4.4
# ctr[300] - expected: 6.0, prediction: 4.9
# ctr[301] - expected: 4.9, prediction: 5.2
# ctr[302] - expected: 5.5, prediction: 4.9
# ctr[303] - expected: 4.5, prediction: 3.8
# ctr[304] - expected: 5.6, prediction: 4.3
# ctr[305] - expected: 5.2, prediction: 5.4
# ctr[306] - expected: 5.6, prediction: 6.0
# ctr[307] - expected: 6.3, prediction: 5.3
# ctr[308] - expected: 5.7, prediction: 6.3
# ctr[309] - expected: 5.8, prediction: 5.4
# ctr[310] - expected: 4.7, prediction: 4.1
# ctr[311] - expected: 4.4, prediction: 3.4
# ctr[312] - expected: 6.4, prediction: 4.5
# ctr[313] - expected: 5.5, prediction: 5.7
# ctr[314] - expected: 5.5, prediction: 4.4
# ctr[315] - expected: 5.8, prediction: 5.6
# ctr[316] - expected: 5.2, prediction: 6.4
# ctr[317] - expected: 6.1, prediction: 5.3
# ctr[318] - expected: 5.3, prediction: 4.9
# ctr[319] - expected: 5.7, prediction: 5.2
# ctr[320] - expected: 4.6, prediction: 5.6
# ctr[321] - expected: 5.6, prediction: 3.7
# ctr[322] - expected: 5.4, prediction: 5.1
# ctr[323] - expected: 5.2, prediction: 4.6
# ctr[324] - expected: 5.6, prediction: 4.7
# ctr[325] - expected: 5.8, prediction: 4.8
# ctr[326] - expected: 5.9, prediction: 5.2
# ctr[327] - expected: 4.7, prediction: 5.8
# ctr[328] - expected: 4.8, prediction: 4.7
# ctr[329] - expected: 4.8, prediction: 2.9
# ctr[330] - expected: 4.8, prediction: 4.3
# ctr[331] - expected: 5.6, prediction: 5.6
# ctr[332] - expected: 4.2, prediction: 4.4
# ctr[333] - expected: 4.8, prediction: 5.1
# ctr[334] - expected: 5.5, prediction: 5.2
# ctr[335] - expected: 5.6, prediction: 6.4
# ctr[336] - expected: 4.9, prediction: 4.2
# ctr[337] - expected: 4.3, prediction: 6.1
# ctr[338] - expected: 5.4, prediction: 6.0
# ctr[339] - expected: 5.3, prediction: 4.0
# ctr[340] - expected: 5.2, prediction: 5.0
# ctr[341] - expected: 5.1, prediction: 4.0
# ctr[342] - expected: 4.4, prediction: 2.2
# ctr[343] - expected: 4.8, prediction: 3.8
# ctr[344] - expected: 6.0, prediction: 4.6
# ctr[345] - expected: 5.3, prediction: 4.1
# ctr[346] - expected: 5.0, prediction: 5.1
# ctr[347] - expected: 5.4, prediction: 6.7
# ctr[348] - expected: 5.4, prediction: 5.5
# ctr[349] - expected: 5.4, prediction: 5.4
# ctr[350] - expected: 5.4, prediction: 4.8
# ctr[351] - expected: 4.8, prediction: 4.8
# ctr[352] - expected: 5.4, prediction: 4.7
# ctr[353] - expected: 5.6, prediction: 4.5
# ctr[354] - expected: 5.1, prediction: 5.9
# ctr[355] - expected: 5.0, prediction: 4.4
# ctr[356] - expected: 5.4, prediction: 3.9
# ctr[357] - expected: 6.3, prediction: 3.6
# ctr[358] - expected: 4.0, prediction: 3.3
# ctr[359] - expected: 5.3, prediction: 3.6
# ctr[360] - expected: 5.7, prediction: 4.7
# ctr[361] - expected: 5.8, prediction: 4.6
# ctr[362] - expected: 5.2, prediction: 3.7
# ctr[363] - expected: 5.5, prediction: 5.9
# ctr[364] - expected: 4.6, prediction: 5.5
# ctr[365] - expected: 5.2, prediction: 6.0
# ctr[366] - expected: 5.4, prediction: 4.3
# ctr[367] - expected: 4.6, prediction: 3.4
# ctr[368] - expected: 4.9, prediction: 4.7
# ctr[369] - expected: 5.0, prediction: 4.9
# ctr[370] - expected: 5.5, prediction: 4.7
# ctr[371] - expected: 5.9, prediction: 6.5
# ctr[372] - expected: 5.5, prediction: 5.5
# ctr[373] - expected: 5.5, prediction: 5.5
# ctr[374] - expected: 6.9, prediction: 5.1
# ctr[375] - expected: 4.2, prediction: 4.5
# ctr[376] - expected: 4.4, prediction: 2.9
# ctr[377] - expected: 3.9, prediction: 3.7
# ctr[378] - expected: 5.0, prediction: 4.8
# ctr[379] - expected: 5.2, prediction: 4.0
# ctr[380] - expected: 6.0, prediction: 6.5
# ctr[381] - expected: 5.4, prediction: 5.5
# ctr[382] - expected: 5.4, prediction: 5.0
# ctr[383] - expected: 5.1, prediction: 4.2
# ctr[384] - expected: 5.4, prediction: 5.0
# ctr[385] - expected: 6.3, prediction: 4.9
# test[385] - values different by 3.1
# ctr[386] - expected: 4.9, prediction: 3.8
# ctr[387] - expected: 4.6, prediction: 4.7
# ctr[388] - expected: 4.7, prediction: 3.9
# ctr[389] - expected: 4.5, prediction: 5.3
# ctr[390] - expected: 5.4, prediction: 6.4
# ctr[391] - expected: 5.1, prediction: 4.6
# ctr[392] - expected: 5.4, prediction: 5.8
# test[393] - values different by 3.2
# ctr[393] - expected: 4.5, prediction: 6.4
# ctr[394] - expected: 4.2, prediction: 5.4
# ctr[395] - expected: 4.8, prediction: 5.0
# ctr[396] - expected: 5.0, prediction: 3.8
# ctr[397] - expected: 4.6, prediction: 5.0
# ctr[398] - expected: 5.2, prediction: 3.4
# ctr[399] - expected: 5.0, prediction: 5.6
# ctr[400] - expected: 4.8, prediction: 5.2
# ctr[401] - expected: 3.5, prediction: 6.0
# ctr[402] - expected: 5.3, prediction: 4.2
# ctr[403] - expected: 4.5, prediction: 3.2
# ctr[404] - expected: 4.7, prediction: 5.4
# ctr[405] - expected: 5.4, prediction: 3.0
# ctr[406] - expected: 5.2, prediction: 6.6
# test[408] - values different by 3.4
# ctr[407] - expected: 4.8, prediction: 6.7
# ctr[408] - expected: 5.3, prediction: 6.5
# ctr[409] - expected: 4.3, prediction: 6.8
# ctr[410] - expected: 4.1, prediction: 6.8
# ctr[411] - expected: 5.3, prediction: 4.2
# ctr[412] - expected: 4.2, prediction: 3.8
# ctr[413] - expected: 4.9, prediction: 5.6
# ctr[414] - expected: 4.9, prediction: 6.4
# ctr[415] - expected: 4.9, prediction: 6.0
# ctr[416] - expected: 4.9, prediction: 5.6
# ctr[417] - expected: 7.3, prediction: 5.8
# ctr[418] - expected: 5.0, prediction: 3.4
# ctr[419] - expected: 5.7, prediction: 4.2
# ctr[420] - expected: 5.8, prediction: 4.2
# ctr[421] - expected: 4.3, prediction: 4.6
# ctr[422] - expected: 5.0, prediction: 5.2
# ctr[423] - expected: 6.1, prediction: 3.2
# ctr[424] - expected: 4.4, prediction: 6.2
# ctr[425] - expected: 5.2, prediction: 3.4
# ctr[426] - expected: 5.0, prediction: 3.8
# ctr[427] - expected: 4.6, prediction: 6.4
# ctr[428] - expected: 5.0, prediction: 4.0
# ctr[429] - expected: 4.3, prediction: 5.4
# ctr[430] - expected: 5.6, prediction: 3.6
# ctr[431] - expected: 3.4, prediction: 4.4
# ctr[432] - expected: 5.0, prediction: 4.8
# ctr[433] - expected: 4.1, prediction: 5.6
# ctr[434] - expected: 4.4, prediction: 6.4
# ctr[435] - expected: 3.1, prediction: 4.8
# ctr[436] - expected: 5.3, prediction: 5.5
# ctr[437] - expected: 5.4, prediction: 6.2
# ctr[438] - expected: 3.8, prediction: 6.2
# ctr[439] - expected: 4.5, prediction: 4.4
# ctr[440] - expected: 4.5, prediction: 4.4
# ctr[441] - expected: 5.2, prediction: 3.2
# ctr[442] - expected: 4.7, prediction: 3.2
# ctr[443] - expected: 4.3, prediction: 3.8
# ctr[444] - expected: 3.5, prediction: 5.4
# ctr[445] - expected: 5.5, prediction: 5.0
# ctr[446] - expected: 5.0, prediction: 5.0
# ctr[447] - expected: 5.8, prediction: 3.2
# ctr[448] - expected: 5.1, prediction: 3.8
# ctr: 448
# nctr: 3
# test[436] - expected: 4.4, prediction: 6.4

# %%
model = build_model()
EPOCHS = 500

# Store training stats
history = model.fit(x_train, arousal_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[PrintDot()])

plot_history(history)
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
model = build_model()

# The patience parameter is the amount of epochs to check for improvement.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(x_train, arousal_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# ..................................................................

# %%
[loss, mae] = model.evaluate(x_test, arousal_y_test, verbose=0)

print("Testing set Mean Abs Error:{:7.2f}".format(mae))
# Out:
# Testing set Mean Abs Error:   0.75

# %%
test_predictions = model.predict(x_test).flatten()

print(len(test_predictions))
print(len(arousal_y_test))
# Out:
# 451
# 451

# %%
ctr=0
nctr=0
for i in range(len(arousal_y_test)):
    diff = abs(test_predictions[i] - arousal_y_test[i])
    if(diff < 1):
        ctr = ctr + 1
        print("ctr[{0:}] - expected: {1:.1f}, prediction: {2:.1f}".format(ctr,test_predictions[i],arousal_y_test[i]))
    else:
        nctr = nctr + 1
        diff = abs(test_predictions[i] - arousal_y_test[i])
        print("test[{}] - values different by {:.1f}".format(i,diff))
    
print("ctr: {}\nnctr: {}".format(ctr,nctr))

print("test[436] - expected: {0:.1f}, prediction: {1:.1f}".format(test_predictions[436],arousal_y_test[436]))
# Out:
# ctr[1] - expected: 6.3, prediction: 7.0
# ctr[2] - expected: 6.2, prediction: 6.5
# ctr[3] - expected: 4.3, prediction: 4.1
# test[3] - values different by 1.1
# ctr[4] - expected: 4.1, prediction: 3.1
# ctr[5] - expected: 5.6, prediction: 6.6
# ctr[6] - expected: 4.5, prediction: 4.6
# ctr[7] - expected: 4.7, prediction: 4.6
# ctr[8] - expected: 5.6, prediction: 5.5
# ctr[9] - expected: 5.1, prediction: 5.9
# test[10] - values different by 1.8
# ctr[10] - expected: 6.3, prediction: 5.3
# ctr[11] - expected: 5.7, prediction: 5.7
# test[13] - values different by 1.3
# test[14] - values different by 1.1
# ctr[12] - expected: 4.9, prediction: 5.3
# ctr[13] - expected: 5.5, prediction: 6.4
# ctr[14] - expected: 5.0, prediction: 4.4
# ctr[15] - expected: 6.2, prediction: 6.0
# ctr[16] - expected: 4.3, prediction: 3.9
# ctr[17] - expected: 4.5, prediction: 4.8
# test[21] - values different by 1.7
# ctr[18] - expected: 4.6, prediction: 5.4
# ctr[19] - expected: 5.3, prediction: 4.8
# ctr[20] - expected: 3.8, prediction: 3.4
# ctr[21] - expected: 5.6, prediction: 6.3
# ctr[22] - expected: 5.7, prediction: 6.1
# ctr[23] - expected: 5.6, prediction: 6.1
# ctr[24] - expected: 5.4, prediction: 5.2
# test[29] - values different by 1.1
# ctr[25] - expected: 4.9, prediction: 3.9
# ctr[26] - expected: 5.4, prediction: 5.3
# test[32] - values different by 1.3
# ctr[27] - expected: 5.8, prediction: 5.3
# ctr[28] - expected: 5.0, prediction: 4.9
# ctr[29] - expected: 4.8, prediction: 4.3
# ctr[30] - expected: 5.0, prediction: 5.9
# ctr[31] - expected: 5.1, prediction: 5.7
# ctr[32] - expected: 4.3, prediction: 3.7
# ctr[33] - expected: 5.6, prediction: 5.8
# ctr[34] - expected: 2.9, prediction: 2.5
# test[41] - values different by 3.1
# ctr[35] - expected: 4.6, prediction: 4.7
# ctr[36] - expected: 5.4, prediction: 6.0
# ctr[37] - expected: 6.2, prediction: 6.3
# test[45] - values different by 1.1
# test[46] - values different by 1.4
# test[47] - values different by 1.1
# ctr[38] - expected: 4.0, prediction: 4.0
# ctr[39] - expected: 5.4, prediction: 5.7
# test[50] - values different by 1.5
# ctr[40] - expected: 5.6, prediction: 4.6
# ctr[41] - expected: 4.8, prediction: 5.5
# ctr[42] - expected: 6.5, prediction: 6.3
# ctr[43] - expected: 6.2, prediction: 6.0
# ctr[44] - expected: 4.5, prediction: 4.9
# ctr[45] - expected: 4.1, prediction: 4.0
# ctr[46] - expected: 5.5, prediction: 5.7
# test[58] - values different by 1.1
# test[59] - values different by 2.7
# test[60] - values different by 1.1
# test[61] - values different by 1.1
# ctr[47] - expected: 5.0, prediction: 5.4
# ctr[48] - expected: 4.0, prediction: 3.3
# test[64] - values different by 1.6
# ctr[49] - expected: 5.6, prediction: 5.9
# ctr[50] - expected: 5.8, prediction: 5.3
# ctr[51] - expected: 6.0, prediction: 5.7
# ctr[52] - expected: 5.3, prediction: 4.9
# test[69] - values different by 1.5
# ctr[53] - expected: 4.9, prediction: 4.2
# ctr[54] - expected: 5.0, prediction: 5.6
# ctr[55] - expected: 5.5, prediction: 6.1
# test[73] - values different by 1.0
# ctr[56] - expected: 5.8, prediction: 5.8
# ctr[57] - expected: 4.8, prediction: 4.8
# ctr[58] - expected: 5.5, prediction: 5.0
# ctr[59] - expected: 4.9, prediction: 4.5
# ctr[60] - expected: 4.1, prediction: 3.3
# ctr[61] - expected: 5.4, prediction: 4.7
# test[80] - values different by 1.7
# ctr[62] - expected: 5.8, prediction: 6.4
# ctr[63] - expected: 4.5, prediction: 4.6
# test[83] - values different by 1.0
# ctr[64] - expected: 4.0, prediction: 3.3
# ctr[65] - expected: 4.1, prediction: 3.8
# ctr[66] - expected: 5.9, prediction: 6.1
# test[87] - values different by 1.4
# ctr[67] - expected: 4.1, prediction: 3.3
# ctr[68] - expected: 3.6, prediction: 2.8
# ctr[69] - expected: 4.1, prediction: 4.5
# ctr[70] - expected: 4.6, prediction: 5.0
# ctr[71] - expected: 5.3, prediction: 5.0
# ctr[72] - expected: 3.1, prediction: 3.1
# ctr[73] - expected: 3.2, prediction: 3.9
# test[95] - values different by 1.3
# ctr[74] - expected: 5.4, prediction: 6.4
# test[97] - values different by 1.0
# ctr[75] - expected: 5.0, prediction: 4.0
# ctr[76] - expected: 3.7, prediction: 4.0
# ctr[77] - expected: 3.3, prediction: 3.6
# test[101] - values different by 2.3
# test[102] - values different by 1.3
# test[103] - values different by 1.6
# test[104] - values different by 1.2
# ctr[78] - expected: 4.8, prediction: 5.7
# ctr[79] - expected: 4.0, prediction: 4.0
# ctr[80] - expected: 5.3, prediction: 5.6
# ctr[81] - expected: 5.3, prediction: 5.4
# ctr[82] - expected: 4.4, prediction: 4.8
# test[110] - values different by 1.1
# ctr[83] - expected: 3.5, prediction: 3.3
# test[112] - values different by 1.9
# ctr[84] - expected: 3.6, prediction: 2.9
# ctr[85] - expected: 3.5, prediction: 3.1
# ctr[86] - expected: 4.2, prediction: 3.4
# ctr[87] - expected: 3.8, prediction: 3.3
# ctr[88] - expected: 4.3, prediction: 4.4
# test[118] - values different by 1.2
# ctr[89] - expected: 5.3, prediction: 4.7
# ctr[90] - expected: 4.0, prediction: 4.7
# ctr[91] - expected: 5.0, prediction: 5.4
# ctr[92] - expected: 4.4, prediction: 3.9
# ctr[93] - expected: 4.2, prediction: 3.6
# test[124] - values different by 1.0
# ctr[94] - expected: 2.9, prediction: 3.3
# test[126] - values different by 1.0
# test[127] - values different by 1.5
# ctr[95] - expected: 4.0, prediction: 3.1
# ctr[96] - expected: 4.0, prediction: 3.6
# ctr[97] - expected: 4.1, prediction: 4.8
# ctr[98] - expected: 3.2, prediction: 2.8
# ctr[99] - expected: 4.9, prediction: 4.3
# ctr[100] - expected: 4.5, prediction: 3.5
# ctr[101] - expected: 5.7, prediction: 5.1
# test[135] - values different by 1.7
# ctr[102] - expected: 5.2, prediction: 4.3
# ctr[103] - expected: 5.0, prediction: 5.9
# ctr[104] - expected: 5.2, prediction: 4.8
# ctr[105] - expected: 3.4, prediction: 2.9
# ctr[106] - expected: 3.8, prediction: 4.1
# ctr[107] - expected: 5.3, prediction: 4.6
# ctr[108] - expected: 5.0, prediction: 5.3
# ctr[109] - expected: 4.6, prediction: 4.3
# ctr[110] - expected: 5.6, prediction: 6.1
# ctr[111] - expected: 4.4, prediction: 3.4
# test[146] - values different by 1.7
# ctr[112] - expected: 4.8, prediction: 5.7
# ctr[113] - expected: 3.2, prediction: 3.9
# ctr[114] - expected: 2.9, prediction: 3.1
# test[150] - values different by 1.4
# ctr[115] - expected: 4.5, prediction: 4.7
# test[152] - values different by 1.3
# test[153] - values different by 1.4
# test[154] - values different by 1.4
# ctr[116] - expected: 3.8, prediction: 3.5
# ctr[117] - expected: 4.6, prediction: 4.0
# ctr[118] - expected: 4.8, prediction: 4.6
# ctr[119] - expected: 3.2, prediction: 3.0
# ctr[120] - expected: 2.6, prediction: 2.4
# ctr[121] - expected: 3.5, prediction: 3.1
# test[161] - values different by 1.4
# ctr[122] - expected: 3.8, prediction: 2.9
# ctr[123] - expected: 4.9, prediction: 5.3
# ctr[124] - expected: 3.5, prediction: 4.3
# ctr[125] - expected: 3.8, prediction: 4.1
# ctr[126] - expected: 4.4, prediction: 4.8
# ctr[127] - expected: 3.6, prediction: 3.0
# ctr[128] - expected: 3.6, prediction: 3.8
# ctr[129] - expected: 4.1, prediction: 4.4
# ctr[130] - expected: 3.4, prediction: 3.2
# ctr[131] - expected: 3.2, prediction: 2.9
# ctr[132] - expected: 3.4, prediction: 3.5
# ctr[133] - expected: 2.7, prediction: 2.7
# ctr[134] - expected: 5.0, prediction: 5.2
# test[175] - values different by 1.3
# test[176] - values different by 1.1
# ctr[135] - expected: 4.7, prediction: 5.2
# ctr[136] - expected: 3.0, prediction: 3.1
# test[179] - values different by 1.7
# ctr[137] - expected: 5.4, prediction: 6.0
# ctr[138] - expected: 4.4, prediction: 5.1
# ctr[139] - expected: 2.9, prediction: 3.3
# ctr[140] - expected: 4.3, prediction: 3.3
# ctr[141] - expected: 5.7, prediction: 5.1
# ctr[142] - expected: 5.0, prediction: 4.2
# ctr[143] - expected: 4.4, prediction: 3.7
# test[187] - values different by 1.3
# ctr[144] - expected: 5.8, prediction: 6.0
# ctr[145] - expected: 4.3, prediction: 4.1
# ctr[146] - expected: 4.5, prediction: 4.0
# ctr[147] - expected: 4.6, prediction: 4.5
# ctr[148] - expected: 3.4, prediction: 2.6
# test[193] - values different by 1.7
# ctr[149] - expected: 5.9, prediction: 6.6
# ctr[150] - expected: 4.5, prediction: 3.6
# ctr[151] - expected: 5.2, prediction: 5.9
# ctr[152] - expected: 5.6, prediction: 4.9
# ctr[153] - expected: 5.4, prediction: 6.2
# ctr[154] - expected: 5.5, prediction: 5.3
# ctr[155] - expected: 6.1, prediction: 5.3
# test[201] - values different by 1.6
# ctr[156] - expected: 4.9, prediction: 4.0
# ctr[157] - expected: 5.4, prediction: 4.7
# ctr[158] - expected: 5.5, prediction: 5.0
# ctr[159] - expected: 5.8, prediction: 5.7
# ctr[160] - expected: 5.4, prediction: 5.8
# ctr[161] - expected: 4.9, prediction: 5.8
# ctr[162] - expected: 4.4, prediction: 4.5
# ctr[163] - expected: 5.6, prediction: 6.0
# test[210] - values different by 2.3
# ctr[164] - expected: 5.0, prediction: 4.1
# ctr[165] - expected: 5.3, prediction: 4.4
# ctr[166] - expected: 5.7, prediction: 6.6
# ctr[167] - expected: 4.2, prediction: 3.5
# test[215] - values different by 1.6
# test[216] - values different by 1.3
# ctr[168] - expected: 5.2, prediction: 4.5
# ctr[169] - expected: 4.4, prediction: 3.7
# ctr[170] - expected: 5.9, prediction: 6.7
# ctr[171] - expected: 6.2, prediction: 6.6
# ctr[172] - expected: 4.1, prediction: 3.6
# ctr[173] - expected: 4.5, prediction: 5.3
# test[223] - values different by 1.1
# ctr[174] - expected: 4.5, prediction: 5.2
# ctr[175] - expected: 4.1, prediction: 3.2
# ctr[176] - expected: 5.3, prediction: 5.7
# test[227] - values different by 1.2
# ctr[177] - expected: 4.8, prediction: 4.6
# test[229] - values different by 1.1
# ctr[178] - expected: 5.6, prediction: 5.0
# ctr[179] - expected: 5.1, prediction: 5.7
# ctr[180] - expected: 6.2, prediction: 5.4
# test[233] - values different by 2.9
# test[234] - values different by 1.1
# ctr[181] - expected: 4.7, prediction: 4.7
# ctr[182] - expected: 4.6, prediction: 5.5
# ctr[183] - expected: 5.8, prediction: 5.9
# ctr[184] - expected: 5.2, prediction: 5.8
# test[239] - values different by 1.1
# ctr[185] - expected: 5.8, prediction: 5.0
# test[241] - values different by 1.3
# test[242] - values different by 1.7
# ctr[186] - expected: 3.2, prediction: 3.3
# ctr[187] - expected: 4.7, prediction: 4.7
# test[245] - values different by 1.4
# ctr[188] - expected: 5.0, prediction: 4.5
# test[247] - values different by 1.2
# ctr[189] - expected: 6.4, prediction: 6.7
# ctr[190] - expected: 5.1, prediction: 5.0
# ctr[191] - expected: 5.6, prediction: 5.6
# ctr[192] - expected: 5.0, prediction: 5.0
# ctr[193] - expected: 4.5, prediction: 3.5
# ctr[194] - expected: 4.3, prediction: 5.0
# ctr[195] - expected: 4.6, prediction: 4.9
# ctr[196] - expected: 5.3, prediction: 5.7
# test[256] - values different by 1.9
# ctr[197] - expected: 5.1, prediction: 5.9
# ctr[198] - expected: 3.5, prediction: 4.5
# ctr[199] - expected: 3.3, prediction: 4.0
# ctr[200] - expected: 5.1, prediction: 5.0
# ctr[201] - expected: 3.4, prediction: 3.7
# ctr[202] - expected: 4.9, prediction: 5.6
# ctr[203] - expected: 5.8, prediction: 6.6
# ctr[204] - expected: 5.1, prediction: 4.2
# ctr[205] - expected: 4.0, prediction: 3.4
# test[266] - values different by 1.5
# test[267] - values different by 1.9
# ctr[206] - expected: 4.6, prediction: 5.0
# ctr[207] - expected: 5.2, prediction: 5.5
# test[270] - values different by 1.2
# ctr[208] - expected: 5.9, prediction: 6.4
# test[272] - values different by 2.2
# ctr[209] - expected: 4.8, prediction: 5.2
# ctr[210] - expected: 5.3, prediction: 6.2
# ctr[211] - expected: 4.6, prediction: 4.5
# ctr[212] - expected: 5.4, prediction: 5.6
# ctr[213] - expected: 4.3, prediction: 3.9
# ctr[214] - expected: 3.3, prediction: 3.0
# ctr[215] - expected: 5.2, prediction: 5.8
# ctr[216] - expected: 2.7, prediction: 3.2
# ctr[217] - expected: 5.3, prediction: 5.5
# ctr[218] - expected: 5.3, prediction: 5.8
# ctr[219] - expected: 3.9, prediction: 3.5
# ctr[220] - expected: 5.3, prediction: 6.1
# test[285] - values different by 1.8
# ctr[221] - expected: 4.8, prediction: 4.8
# test[287] - values different by 1.5
# test[288] - values different by 1.9
# ctr[222] - expected: 4.2, prediction: 3.8
# ctr[223] - expected: 5.0, prediction: 4.2
# test[291] - values different by 1.0
# ctr[224] - expected: 5.8, prediction: 6.7
# test[293] - values different by 1.5
# test[294] - values different by 1.9
# test[295] - values different by 1.5
# test[296] - values different by 1.7
# ctr[225] - expected: 5.5, prediction: 6.5
# test[298] - values different by 1.0
# ctr[226] - expected: 5.8, prediction: 6.5
# ctr[227] - expected: 4.5, prediction: 5.1
# test[301] - values different by 1.5
# test[302] - values different by 1.1
# ctr[228] - expected: 6.2, prediction: 5.4
# ctr[229] - expected: 5.1, prediction: 5.5
# test[305] - values different by 1.0
# ctr[230] - expected: 6.4, prediction: 6.3
# test[307] - values different by 1.3
# test[308] - values different by 1.2
# ctr[231] - expected: 4.4, prediction: 4.6
# ctr[232] - expected: 4.8, prediction: 4.6
# ctr[233] - expected: 4.8, prediction: 5.4
# test[312] - values different by 1.1
# ctr[234] - expected: 5.7, prediction: 6.5
# ctr[235] - expected: 5.8, prediction: 5.8
# ctr[236] - expected: 5.6, prediction: 6.2
# ctr[237] - expected: 6.2, prediction: 5.7
# test[317] - values different by 1.1
# ctr[238] - expected: 5.9, prediction: 6.1
# ctr[239] - expected: 4.2, prediction: 4.6
# ctr[240] - expected: 4.9, prediction: 5.6
# test[321] - values different by 1.4
# test[322] - values different by 1.1
# ctr[241] - expected: 5.7, prediction: 5.5
# ctr[242] - expected: 5.3, prediction: 6.0
# test[325] - values different by 2.0
# ctr[243] - expected: 4.2, prediction: 3.8
# ctr[244] - expected: 5.3, prediction: 4.4
# test[328] - values different by 1.5
# ctr[245] - expected: 4.2, prediction: 3.9
# test[330] - values different by 1.4
# ctr[246] - expected: 4.0, prediction: 3.2
# ctr[247] - expected: 5.1, prediction: 5.6
# ctr[248] - expected: 5.1, prediction: 4.4
# test[334] - values different by 1.3
# ctr[249] - expected: 4.7, prediction: 4.4
# test[336] - values different by 1.1
# ctr[250] - expected: 5.2, prediction: 6.1
# ctr[251] - expected: 5.8, prediction: 6.0
# test[339] - values different by 2.0
# test[340] - values different by 1.0
# test[341] - values different by 1.0
# ctr[252] - expected: 4.0, prediction: 3.4
# test[343] - values different by 1.6
# test[344] - values different by 1.0
# ctr[253] - expected: 4.9, prediction: 4.4
# ctr[254] - expected: 5.8, prediction: 5.7
# test[347] - values different by 1.5
# ctr[255] - expected: 5.3, prediction: 5.9
# ctr[256] - expected: 5.3, prediction: 4.8
# ctr[257] - expected: 4.3, prediction: 5.1
# ctr[258] - expected: 5.1, prediction: 5.8
# ctr[259] - expected: 6.0, prediction: 6.7
# ctr[260] - expected: 5.6, prediction: 5.3
# ctr[261] - expected: 5.0, prediction: 5.0
# ctr[262] - expected: 5.5, prediction: 5.5
# ctr[263] - expected: 6.3, prediction: 6.7
# ctr[264] - expected: 3.7, prediction: 3.5
# ctr[265] - expected: 5.1, prediction: 5.0
# test[359] - values different by 1.2
# ctr[266] - expected: 5.4, prediction: 6.2
# test[361] - values different by 1.2
# test[362] - values different by 1.1
# ctr[267] - expected: 5.2, prediction: 5.5
# test[364] - values different by 1.1
# ctr[268] - expected: 5.0, prediction: 4.3
# ctr[269] - expected: 4.2, prediction: 4.7
# ctr[270] - expected: 5.0, prediction: 5.6
# ctr[271] - expected: 4.9, prediction: 5.4
# ctr[272] - expected: 5.3, prediction: 5.2
# ctr[273] - expected: 5.6, prediction: 6.5
# test[371] - values different by 2.2
# ctr[274] - expected: 5.7, prediction: 5.4
# test[373] - values different by 1.4
# ctr[275] - expected: 4.1, prediction: 4.5
# ctr[276] - expected: 4.1, prediction: 3.4
# ctr[277] - expected: 3.6, prediction: 2.9
# test[377] - values different by 1.1
# ctr[278] - expected: 5.5, prediction: 5.1
# ctr[279] - expected: 5.7, prediction: 6.3
# ctr[280] - expected: 5.6, prediction: 5.8
# ctr[281] - expected: 5.1, prediction: 5.7
# ctr[282] - expected: 4.8, prediction: 4.1
# ctr[283] - expected: 5.3, prediction: 6.0
# ctr[284] - expected: 6.1, prediction: 6.8
# ctr[285] - expected: 6.3, prediction: 7.0
# test[386] - values different by 1.4
# ctr[286] - expected: 4.4, prediction: 4.7
# test[388] - values different by 1.7
# ctr[287] - expected: 4.7, prediction: 3.9
# test[390] - values different by 1.1
# ctr[288] - expected: 5.0, prediction: 5.4
# ctr[289] - expected: 5.6, prediction: 6.0
# test[393] - values different by 1.2
# ctr[290] - expected: 5.9, prediction: 5.2
# ctr[291] - expected: 4.3, prediction: 4.6
# ctr[292] - expected: 4.4, prediction: 4.8
# ctr[293] - expected: 5.0, prediction: 5.2
# test[398] - values different by 1.0
# test[399] - values different by 1.2
# test[400] - values different by 2.0
# ctr[294] - expected: 4.8, prediction: 4.2
# test[402] - values different by 1.3
# ctr[295] - expected: 5.7, prediction: 5.0
# ctr[296] - expected: 4.4, prediction: 5.2
# ctr[297] - expected: 5.4, prediction: 5.6
# test[406] - values different by 1.3
# ctr[298] - expected: 5.7, prediction: 5.4
# ctr[299] - expected: 5.9, prediction: 5.6
# test[409] - values different by 2.3
# ctr[300] - expected: 5.6, prediction: 6.3
# test[411] - values different by 2.1
# test[412] - values different by 1.3
# ctr[301] - expected: 5.2, prediction: 4.4
# ctr[302] - expected: 4.9, prediction: 4.4
# test[415] - values different by 2.2
# ctr[303] - expected: 5.2, prediction: 4.4
# ctr[304] - expected: 4.5, prediction: 4.8
# test[418] - values different by 1.7
# ctr[305] - expected: 5.9, prediction: 5.4
# test[420] - values different by 1.6
# test[421] - values different by 1.7
# ctr[306] - expected: 6.2, prediction: 6.2
# test[423] - values different by 1.6
# ctr[307] - expected: 5.0, prediction: 4.4
# test[425] - values different by 1.6
# ctr[308] - expected: 4.3, prediction: 4.6
# ctr[309] - expected: 5.2, prediction: 4.6
# ctr[310] - expected: 5.6, prediction: 4.7
# ctr[311] - expected: 4.6, prediction: 4.4
# test[430] - values different by 1.3
# test[431] - values different by 1.1
# ctr[312] - expected: 6.0, prediction: 7.0
# ctr[313] - expected: 3.9, prediction: 3.0
# ctr[314] - expected: 5.4, prediction: 4.6
# ctr[315] - expected: 3.9, prediction: 4.4
# ctr[316] - expected: 4.5, prediction: 5.2
# ctr[317] - expected: 3.3, prediction: 3.2
# ctr[318] - expected: 5.7, prediction: 5.2
# ctr[319] - expected: 5.4, prediction: 5.0
# ctr[320] - expected: 3.3, prediction: 3.6
# test[441] - values different by 1.0
# test[442] - values different by 1.1
# ctr[321] - expected: 4.7, prediction: 4.6
# ctr[322] - expected: 5.1, prediction: 5.2
# ctr[323] - expected: 3.6, prediction: 3.8
# ctr[324] - expected: 2.7, prediction: 3.6
# ctr[325] - expected: 6.1, prediction: 5.2
# ctr[326] - expected: 4.8, prediction: 4.6
# test[449] - values different by 1.2
# ctr[327] - expected: 5.6, prediction: 5.8
# ctr: 327
# nctr: 124
# test[436] - expected: 4.5, prediction: 5.2
